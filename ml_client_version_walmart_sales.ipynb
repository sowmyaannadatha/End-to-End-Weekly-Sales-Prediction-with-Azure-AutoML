# %%
#!pip uninstall azure-ai-ml azure-core msrest -y
#!pip install azure-ai-ml==1.28.1 azure-identity --upgrade

# %%
import json
from azure.ai.ml import MLClient
from azure.identity import DefaultAzureCredential
from azure.identity import AzureCliCredential
from azure.ai.ml import MLClient

credential = AzureCliCredential()  # uses az login session

# ---------------------------------------------------------
# Load workspace credentials from config.json
# ---------------------------------------------------------
with open("config.json") as f:
    config = json.load(f)

subscription_id = config["subscription_id"]
resource_group = config["resource_group"]
workspace_name = config["workspace_name"]

# ---------------------------------------------------------
# Connect to ML Workspace
# ---------------------------------------------------------
ml_client = MLClient(
    credential=credential,
    subscription_id=subscription_id,
    resource_group_name=resource_group,
    workspace_name=workspace_name,
)

# %%
# ===============================
# Dataset Preparation
# ===============================
# Load dataset from local or Azure datastore
import pandas as pd
data_path = './walmart_sales_dataset_kaggle/train.csv'  # e.g., Favorita or Walmart dataset
df = pd.read_csv(data_path)
df.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  2010-02-05      24924.50      False
# 1      1     1  2010-02-12      46039.49       True
# 2      1     1  2010-02-19      41595.55      False
# 3      1     1  2010-02-26      19403.54      False
# 4      1     1  2010-03-05      21827.90      False

# %%
# ===============================
# Feature Engineering

# ===============================
df.columns = df.columns.str.strip().str.lower()
# Now columns are: 'store', 'dept', 'date', 'weekly_sales', 'isholiday'

# ===============================
# Convert 'date' to datetime safely
# ===============================
df['date'] = pd.to_datetime(df['date'], errors='coerce')
df = df.dropna(subset=['date'])  # drop rows without valid dates

# ===============================
# Basic feature engineering
# ===============================
df['day_of_week'] = df['date'].dt.dayofweek
df['month'] = df['date'].dt.month
df['year'] = df['date'].dt.year
df['week_of_year'] = df['date'].dt.isocalendar().week.astype(int)

# ===============================
# Rolling features (7-day and 30-day)
# ===============================
df = df.sort_values(['store', 'dept', 'date'])
df['rolling_7'] = df.groupby(['store', 'dept'])['weekly_sales'].transform(lambda x: x.rolling(7, min_periods=1).mean())
df['rolling_30'] = df.groupby(['store', 'dept'])['weekly_sales'].transform(lambda x: x.rolling(30, min_periods=1).mean())

# ===============================
# Handle remaining NaNs
# ===============================
df.fillna(0, inplace=True)
df.to_csv("./walmart_data/walmart.csv", index=False)

df.head()
# Out:
#    store  dept       date  weekly_sales  isholiday  day_of_week  month  year  \
# 0      1     1 2010-02-05      24924.50      False            4      2  2010
# 1      1     1 2010-02-12      46039.49       True            4      2  2010
# 2      1     1 2010-02-19      41595.55      False            4      2  2010
# 3      1     1 2010-02-26      19403.54      False            4      2  2010
# 4      1     1 2010-03-05      21827.90      False            4      3  2010
#
#    week_of_year     rolling_7    rolling_30
# 0             5  24924.500000  24924.500000
# 1             6  35481.995000  35481.995000
# 2             7  37519.846667  37519.846667
# 3             8  32990.770000  32990.770000
# 4             9  30758.196000  30758.196000

# %%
# ---------------------------------------------------------
# Upload Walmart Dataset 
# ---------------------------------------------------------

from azure.ai.ml.entities import Data
# Register dataset
walmart_data = ml_client.data.create_or_update(
    Data(
        
        name="walmart-dataset",
        description="Feature engineered Walmart Kaggle dataset",
        path="./walmart_data",   # 👈 folder with MLTable
        type="mltable",
    )
)

print("Registered dataset:", walmart_data.name, walmart_data.version)
# Out:
# Registered dataset: walmart-dataset 3

# %%
# ---------------------------------------------------------
# Configure AutoML Regression Job for Free Tier
# ---------------------------------------------------------
from azure.ai.ml import MLClient
from azure.ai.ml import Input
from azure.ai.ml.automl import regression
from azure.ai.ml import automl
# Use dataset by name and version
training_data_input = Input(
    type="mltable",
    path="azureml:walmart-dataset:3"  # Registered MLTable dataset
)

regression_job = regression(
    compute="cpu-cluster",
    experiment_name="walmart-automl-regression",
    training_data=training_data_input,  # ✅ pass Input object, not Data object
    target_column_name="weekly_sales",
    primary_metric="r2_score",
    n_cross_validations=3,
    outputs={"best_model": {"type": "mlflow_model"}}  # ✅ register best model
)

regression_job.set_limits(
    timeout_minutes=30,
    max_trials=4,
    max_concurrent_trials=1
)


# Submit job
returned_job = ml_client.jobs.create_or_update(regression_job)
ml_client.jobs.stream(returned_job.name)

# %%
# Get the AutoML parent job
automl_job = ml_client.jobs.get(returned_job.name)

# List child jobs (trials)
children = list(ml_client.jobs.list(parent_job_name=automl_job.name))

# Find best trial
best_child = max(children, key=lambda x: float(x.properties.get("score", "-inf")))
print("Best child run:", best_child.name, "Score:", best_child.properties["score"])
# Out:
# Best child run: brave_clock_vn26600n18_2 Score: 0.9805759765144004

# %%
# ---------------------------------------------------------
# 5. Retrieve Best Model
# ---------------------------------------------------------
#best_child_run = ml_client.jobs.get(returned_job.name).properties["best_child_run_id"]
#print("Best run ID:", best_child_run)

best_model = ml_client.models.get(name="best",version=1)
print(best_model)

# %%
# Download best model locally
ml_client.models.download(
    name="best",
    version=1,
    download_path="./local_model"
)
# Out:
# Downloading the model ExperimentRun/dcid.brave_clock_vn26600n18_2/outputs/mlflow-model at ./local_model\best\mlflow-model

# %%
import mlflow


# Load MLflow model
model = mlflow.pyfunc.load_model("./local_model/best/mlflow-model")

# Example: use a row from your engineered walmart.csv
sample = pd.read_csv("./walmart_data/walmart.csv").head(10).drop(columns=["weekly_sales"])
# Cast columns to match MLTable schema
sample ['store'] = sample ['store'].astype(str)      # AutoML expects string
sample ['dept'] = sample ['dept'].astype(int)        # AutoML expects long (int64)
sample['isholiday'] = sample['isholiday'].astype(bool)

# Dates already handled as datetime
sample['date'] = pd.to_datetime(sample['date'], errors='coerce')

# Save clean dataset
sample.to_csv("walmart.csv", index=False)

# Predict
prediction = model.predict(sample)
print("Predicted Weekly Sales:", prediction)
# Out:
# 2025/08/22 23:30:08 WARNING mlflow.utils.requirements_utils: Detected one or more mismatches between the model's dependencies and the current Python environment:
#  - asttokens (current: uninstalled, required: asttokens==3.0.0)
#  - attrs (current: 21.4.0, required: attrs==25.3.0)
#  - azure-core (current: 1.35.0, required: azure-core==1.33.0)
#  - azure-identity (current: 1.24.0, required: azure-identity==1.21.0)
#  - azure-mgmt-containerregistry (current: 13.0.0, required: azure-mgmt-containerregistry==10.3.0)
#  - azure-mgmt-core (current: 1.6.0, required: azure-mgmt-core==1.5.0)
#  - azure-mgmt-keyvault (current: 11.0.0, required: azure-mgmt-keyvault==10.3.1)
#  - azure-mgmt-network (current: 29.0.0, required: azure-mgmt-network==28.1.0)
#  - azure-mgmt-resource (current: 24.0.0, required: azure-mgmt-resource==23.3.0)
#  - azure-mgmt-storage (current: 23.0.0, required: azure-mgmt-storage==22.1.1)
#  - azure-storage-blob (current: 12.26.0, required: azure-storage-blob==12.19.0)
#  - azure-storage-queue (current: 12.13.0, required: azure-storage-queue==12.12.0)
#  - azureml-core (current: 1.60.0.post1, required: azureml-core==1.60.0)
#  - azureml-inference-server-http (current: 1.5.0, required: azureml-inference-server-http==1.4.0)
#  - azureml-mlflow (current: 1.60.0.post1, required: azureml-mlflow==1.60.0)
#  - azureml-pipeline-core (current: uninstalled, required: azureml-pipeline-core==1.60.0)
#  - bcrypt (current: 3.2.0, required: bcrypt==4.3.0)
#  - certifi (current: 2025.8.3, required: certifi==2025.1.31)
#  - cffi (current: 1.15.1, required: cffi==1.17.1)
#  - charset-normalizer (current: 2.0.4, required: charset-normalizer==3.4.1)
#  - cmdstanpy (current: uninstalled, required: cmdstanpy==1.2.5)
#  - comm (current: 0.2.3, required: comm==0.2.2)
#  - contourpy (current: uninstalled, required: contourpy==1.3.0)
#  - convertdate (current: uninstalled, required: convertdate==2.4.0)
#  - cryptography (current: 37.0.1, required: cryptography==44.0.2)
#  - cycler (current: 0.11.0, required: cycler==0.12.1)
#  - cython (current: 0.29.32, required: cython==3.0.12)
#  - dask (current: 2022.7.0, required: dask==2023.2.0)
#  - databricks-sdk (current: 0.63.0, required: databricks-sdk==0.50.0)
#  - debugpy (current: 1.8.16, required: debugpy==1.8.14)
#  - decorator (current: 5.1.1, required: decorator==5.2.1)
#  - dill (current: 0.3.4, required: dill==0.3.9)
#  - distributed (current: 2022.7.0, required: distributed==2023.2.0)
#  - econml (current: 0.16.0, required: econml==0.15.1)
#  - ephem (current: uninstalled, required: ephem==4.2)
#  - exceptiongroup (current: 1.3.0, required: exceptiongroup==1.2.2)
#  - executing (current: uninstalled, required: executing==2.2.0)
#  - fire (current: 0.7.1, required: fire==0.7.0)
#  - flask (current: 3.1.1, required: flask==3.0.3)
#  - flask-cors (current: 6.0.1, required: flask-cors==5.0.1)
#  - fonttools (current: 4.25.0, required: fonttools==4.57.0)
#  - fsspec (current: 2022.7.1, required: fsspec==2025.3.2)
#  - gitpython (current: 3.1.45, required: gitpython==3.1.44)
#  - google-api-core (current: uninstalled, required: google-api-core==2.24.2)
#  - google-auth (current: 2.40.3, required: google-auth==2.38.0)
#  - googleapis-common-protos (current: uninstalled, required: googleapis-common-protos==1.70.0)
#  - gunicorn (current: uninstalled, required: gunicorn==23.0.0)
#  - idna (current: 3.3, required: idna==3.10)
#  - importlib-metadata (current: 8.2.0, required: importlib-metadata==7.2.1)
#  - ipython (current: 7.31.1, required: ipython==8.18.1)
#  - jedi (current: 0.18.1, required: jedi==0.19.2)
#  - jsonpickle (current: 4.1.1, required: jsonpickle==4.0.5)
#  - jsonschema (current: 4.16.0, required: jsonschema==4.23.0)
#  - jsonschema-specifications (current: uninstalled, required: jsonschema-specifications==2024.10.1)
#  - jupyter-client (current: 7.3.4, required: jupyter-client==8.6.3)
#  - jupyter-core (current: 5.8.1, required: jupyter-core==5.7.2)
#  - kiwisolver (current: 1.4.2, required: kiwisolver==1.4.7)
#  - lunarcalendar (current: uninstalled, required: lunarcalendar==0.0.9)
#  - matplotlib (current: 3.5.2, required: matplotlib==3.9.4)
#  - matplotlib-inline (current: 0.1.6, required: matplotlib-inline==0.1.7)
#  - mlflow-skinny (current: 2.22.1, required: mlflow-skinny==2.15.1)
#  - mltable (current: uninstalled, required: mltable==1.6.1)
#  - msal (current: 1.33.0, required: msal==1.32.0)
#  - msgpack (current: 1.0.3, required: msgpack==1.1.0)
#  - nest-asyncio (current: 1.5.5, required: nest-asyncio==1.6.0)
#  - numba (current: 0.55.1, required: numba==0.56.4)
#  - oauthlib (current: 3.3.1, required: oauthlib==3.2.2)
#  - onnx (current: 1.15.0, required: onnx==1.17.0)
#  - onnxruntime (current: 1.17.1, required: onnxruntime==1.17.3)
#  - opencensus (current: uninstalled, required: opencensus==0.11.4)
#  - opencensus-context (current: uninstalled, required: opencensus-context==0.1.3)
#  - opencensus-ext-azure (current: uninstalled, required: opencensus-ext-azure==1.1.14)
#  - opentelemetry-api (current: 1.36.0, required: opentelemetry-api==1.32.0)
#  - opentelemetry-sdk (current: 1.36.0, required: opentelemetry-sdk==1.32.0)
#  - opentelemetry-semantic-conventions (current: 0.57b0, required: opentelemetry-semantic-conventions==0.53b0)
#  - packaging (current: 21.3, required: packaging==24.2)
#  - paramiko (current: 2.8.1, required: paramiko==3.5.1)
#  - parso (current: 0.8.3, required: parso==0.8.4)
#  - partd (current: 1.2.0, required: partd==1.4.2)
#  - pathspec (current: 0.9.0, required: pathspec==0.12.1)
#  - patsy (current: 0.5.2, required: patsy==1.0.1)
#  - pexpect (current: 4.8.0, required: pexpect==4.9.0)
#  - pillow (current: 9.2.0, required: pillow==11.2.1)
#  - pkginfo (current: 1.8.2, required: pkginfo==1.12.1.2)
#  - platformdirs (current: 2.5.2, required: platformdirs==4.3.7)
#  - prompt-toolkit (current: 3.0.20, required: prompt-toolkit==3.0.50)
#  - prophet (current: uninstalled, required: prophet==1.1.4)
#  - proto-plus (current: uninstalled, required: proto-plus==1.26.1)
#  - protobuf (current: 3.20.3, required: protobuf==5.29.4)
#  - pure-eval (current: uninstalled, required: pure-eval==0.2.3)
#  - pyarrow (current: 11.0.0, required: pyarrow==14.0.2)
#  - pyasn1 (current: 0.4.8, required: pyasn1==0.6.1)
#  - pyasn1-modules (current: 0.2.8, required: pyasn1-modules==0.4.2)
#  - pycparser (current: 2.21, required: pycparser==2.22)
#  - pydantic (current: 2.11.7, required: pydantic==2.9.2)
#  - pydantic-core (current: 2.33.2, required: pydantic-core==2.23.4)
#  - pydantic-settings (current: 2.10.1, required: pydantic-settings==2.8.1)
#  - pygments (current: 2.11.2, required: pygments==2.19.1)
#  - pyjwt (current: 2.4.0, required: pyjwt==2.10.1)
#  - pymeeus (current: uninstalled, required: pymeeus==0.5.12)
#  - pyopenssl (current: 22.0.0, required: pyopenssl==25.0.0)
#  - pyparsing (current: 3.0.9, required: pyparsing==3.2.3)
#  - python-dateutil (current: 2.8.2, required: python-dateutil==2.9.0.post0)
#  - python-dotenv (current: 1.1.1, required: python-dotenv==1.1.0)
#  - pytz (current: 2022.1, required: pytz==2024.2)
#  - pyzmq (current: 27.0.1, required: pyzmq==26.4.0)
#  - referencing (current: uninstalled, required: referencing==0.36.2)
#  - requests (current: 2.28.1, required: requests==2.32.3)
#  - rpds-py (current: uninstalled, required: rpds-py==0.24.0)
#  - rsa (current: 4.9.1, required: rsa==4.9)
#  - scipy (current: 1.9.1, required: scipy==1.10.1)
#  - six (current: 1.16.0, required: six==1.17.0)
#  - stack-data (current: uninstalled, required: stack-data==0.6.3)
#  - stanio (current: uninstalled, required: stanio==0.5.1)
#  - statsmodels (current: 0.13.2, required: statsmodels==0.13.5)
#  - tabulate (current: 0.8.10, required: tabulate==0.9.0)
#  - tblib (current: 1.7.0, required: tblib==3.1.0)
#  - termcolor (current: 3.1.0, required: termcolor==3.0.1)
#  - toolz (current: 0.11.2, required: toolz==1.0.0)
#  - tornado (current: 6.1, required: tornado==6.4.2)
#  - tqdm (current: 4.64.1, required: tqdm==4.67.1)
#  - wcwidth (current: 0.2.5, required: wcwidth==0.2.13)
#  - wrapt (current: 1.14.1, required: wrapt==1.16.0)
#  - xgboost (current: 2.1.4, required: xgboost==1.5.2)
#  - zict (current: 2.1.0, required: zict==3.0.0)
#  - zipp (current: 3.8.0, required: zipp==3.21.0)
# To fix the mismatches, call `mlflow.pyfunc.get_model_dependencies(model_uri)` to fetch the model's environment and install dependencies using the resulting environment file.
# Predicted Weekly Sales: [24294.40945699 40575.95483054 37210.49598947 27877.87220515
#  27499.04705998 26364.52126504 25515.23061713 28077.24454628
#  55138.10967538 36689.71842458]

# %%
import mlflow

# Point to your local model folder or Azure ML artifact URI
model_uri = "./local_model/best/mlflow-model"

# Get environment spec
env = mlflow.pyfunc.get_model_dependencies(model_uri)

# Save environment to file
with open("conda.yaml", "w") as f:
    f.write(env)
# Out:
# 2025/08/22 23:33:52 INFO mlflow.pyfunc: To install the dependencies that were used to train the model, run the following command: '%pip install -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt'.

# %%
# %pip install -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt
# Out:
# Requirement already satisfied: adal==1.2.7 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 1)) (1.2.7)
# Requirement already satisfied: annotated-types==0.7.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: applicationinsights==0.11.10 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 3)) (0.11.10)
# Requirement already satisfied: arch==5.6.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 4)) (5.6.0)
# Requirement already satisfied: argcomplete==3.6.2 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 5)) (3.6.2)
# Collecting asttokens==3.0.0
#   Downloading asttokens-3.0.0-py3-none-any.whl (26 kB)
# Collecting attrs==25.3.0
#   Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
#      ---------------------------------------- 63.8/63.8 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: azure-common==1.1.28 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 8)) (1.1.28)
# Collecting azure-core==1.33.0
#   Downloading azure_core-1.33.0-py3-none-any.whl (207 kB)
#      -------------------------------------- 207.1/207.1 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: azure-graphrbac==0.61.2 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 10)) (0.61.2)
# Collecting azure-identity==1.21.0
#   Downloading azure_identity-1.21.0-py3-none-any.whl (189 kB)
#      -------------------------------------- 189.2/189.2 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: azure-mgmt-authorization==4.0.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 12)) (4.0.0)
# Collecting azure-mgmt-containerregistry==10.3.0
#   Downloading azure_mgmt_containerregistry-10.3.0-py3-none-any.whl (2.3 MB)
#      ---------------------------------------- 2.3/2.3 MB 10.5 MB/s eta 0:00:00
# Collecting azure-mgmt-core==1.5.0
#   Using cached azure_mgmt_core-1.5.0-py3-none-any.whl (30 kB)
# Collecting azure-mgmt-keyvault==10.3.1
#   Using cached azure_mgmt_keyvault-10.3.1-py3-none-any.whl (901 kB)
# Collecting azure-mgmt-network==28.1.0
#   Using cached azure_mgmt_network-28.1.0-py3-none-any.whl (575 kB)
# Collecting azure-mgmt-resource==23.3.0
#   Downloading azure_mgmt_resource-23.3.0-py3-none-any.whl (2.9 MB)
#      ---------------------------------------- 2.9/2.9 MB 10.8 MB/s eta 0:00:00
# Collecting azure-mgmt-storage==22.1.1
#   Downloading azure_mgmt_storage-22.1.1-py3-none-any.whl (569 kB)
#      -------------------------------------- 569.5/569.5 kB 7.1 MB/s eta 0:00:00
# Collecting azure-storage-blob==12.19.0
#   Using cached azure_storage_blob-12.19.0-py3-none-any.whl (394 kB)
# Collecting azure-storage-queue==12.12.0
#   Downloading azure_storage_queue-12.12.0-py3-none-any.whl (182 kB)
#      -------------------------------------- 182.4/182.4 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: azureml-automl-core==1.60.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 21)) (1.60.0)
# Requirement already satisfied: azureml-automl-runtime==1.60.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 22)) (1.60.0)
# Collecting azureml-core==1.60.0
#   Downloading azureml_core-1.60.0-py3-none-any.whl (3.3 MB)
#      ---------------------------------------- 3.3/3.3 MB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: azureml-dataprep==5.1.6 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 24)) (5.1.6)
# Requirement already satisfied: azureml-dataprep-native==41.0.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 25)) (41.0.0)
# Requirement already satisfied: azureml-dataprep-rslex==2.22.5 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 26)) (2.22.5)
# Requirement already satisfied: azureml-dataset-runtime==1.60.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 27)) (1.60.0)
# Requirement already satisfied: azureml-defaults==1.60.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 28)) (1.60.0)
# Collecting azureml-inference-server-http==1.4.0
#   Downloading azureml_inference_server_http-1.4.0-py3-none-any.whl (42 kB)
#      ---------------------------------------- 42.0/42.0 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: azureml-interpret==1.60.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 30)) (1.60.0)
# Collecting azureml-mlflow==1.60.0
#   Using cached azureml_mlflow-1.60.0-py3-none-any.whl (1.0 MB)
# Collecting azureml-pipeline-core==1.60.0
#   Downloading azureml_pipeline_core-1.60.0-py3-none-any.whl (313 kB)
#      -------------------------------------- 313.8/313.8 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: azureml-responsibleai==1.60.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 33)) (1.60.0)
# Requirement already satisfied: azureml-telemetry==1.60.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 34)) (1.60.0)
# Requirement already satisfied: azureml-train-automl==1.60.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 35)) (1.60.0)
# Requirement already satisfied: azureml-train-automl-client==1.60.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 36)) (1.60.0)
# Requirement already satisfied: azureml-train-automl-runtime==1.60.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 37)) (1.60.0)
# Requirement already satisfied: azureml-train-core==1.60.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 38)) (1.60.0)
# Requirement already satisfied: azureml-train-restclients-hyperdrive==1.60.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 39)) (1.60.0)
# Requirement already satisfied: azureml-training-tabular==1.60.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 40)) (1.60.0)
# Requirement already satisfied: backports-tempfile==1.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 41)) (1.0)
# Requirement already satisfied: backports-weakref==1.0.post1 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 42)) (1.0.post1)
# Collecting bcrypt==4.3.0
#   Using cached bcrypt-4.3.0-cp39-abi3-win_amd64.whl (152 kB)
# Requirement already satisfied: blinker==1.9.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 44)) (1.9.0)
# Requirement already satisfied: bokeh==2.4.3 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 45)) (2.4.3)
# Requirement already satisfied: cachetools==5.5.2 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 46)) (5.5.2)
# Collecting certifi==2025.1.31
#   Downloading certifi-2025.1.31-py3-none-any.whl (166 kB)
#      -------------------------------------- 166.4/166.4 kB 5.0 MB/s eta 0:00:00
# Collecting cffi==1.17.1
#   Downloading cffi-1.17.1-cp39-cp39-win_amd64.whl (181 kB)
#      -------------------------------------- 181.3/181.3 kB 5.5 MB/s eta 0:00:00
# Collecting charset-normalizer==3.4.1
#   Downloading charset_normalizer-3.4.1-cp39-cp39-win_amd64.whl (102 kB)
#      -------------------------------------- 102.8/102.8 kB 6.2 MB/s eta 0:00:00
# Collecting cmdstanpy==1.2.5
#   Downloading cmdstanpy-1.2.5-py3-none-any.whl (94 kB)
#      ---------------------------------------- 94.5/94.5 kB ? eta 0:00:00
# Requirement already satisfied: coloredlogs==15.0.1 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 51)) (15.0.1)
# Collecting comm==0.2.2
#   Downloading comm-0.2.2-py3-none-any.whl (7.2 kB)
# Requirement already satisfied: contextlib2==21.6.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 53)) (21.6.0)
# Collecting contourpy==1.3.0
#   Downloading contourpy-1.3.0-cp39-cp39-win_amd64.whl (211 kB)
#      -------------------------------------- 211.8/211.8 kB 6.5 MB/s eta 0:00:00
# Collecting convertdate==2.4.0
#   Downloading convertdate-2.4.0-py3-none-any.whl (47 kB)
#      ---------------------------------------- 47.9/47.9 kB ? eta 0:00:00
# Collecting cryptography==44.0.2
#   Downloading cryptography-44.0.2-cp39-abi3-win_amd64.whl (3.2 MB)
#      ---------------------------------------- 3.2/3.2 MB 8.5 MB/s eta 0:00:00
# Collecting cycler==0.12.1
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting cython==3.0.12
#   Downloading Cython-3.0.12-cp39-cp39-win_amd64.whl (2.8 MB)
#      ---------------------------------------- 2.8/2.8 MB 8.5 MB/s eta 0:00:00
# Collecting dask==2023.2.0
#   Downloading dask-2023.2.0-py3-none-any.whl (1.2 MB)
#      ---------------------------------------- 1.2/1.2 MB 10.4 MB/s eta 0:00:00
# Collecting databricks-sdk==0.50.0
#   Downloading databricks_sdk-0.50.0-py3-none-any.whl (692 kB)
#      -------------------------------------- 692.3/692.3 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: dataclasses==0.6 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 61)) (0.6)
# Collecting debugpy==1.8.14
#   Downloading debugpy-1.8.14-cp39-cp39-win_amd64.whl (5.2 MB)
#      ---------------------------------------- 5.2/5.2 MB 8.2 MB/s eta 0:00:00
# Collecting decorator==5.2.1
#   Downloading decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Requirement already satisfied: deprecated==1.2.18 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 64)) (1.2.18)
# Requirement already satisfied: dice-ml==0.11 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 65)) (0.11)
# Collecting dill==0.3.9
#   Downloading dill-0.3.9-py3-none-any.whl (119 kB)
#      -------------------------------------- 119.4/119.4 kB 7.3 MB/s eta 0:00:00
# Collecting distributed==2023.2.0
#   Downloading distributed-2023.2.0-py3-none-any.whl (934 kB)
#      -------------------------------------- 934.8/934.8 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: distro==1.9.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 68)) (1.9.0)
# Requirement already satisfied: docker==7.1.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 69)) (7.1.0)
# Requirement already satisfied: dotnetcore2==3.1.23 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 70)) (3.1.23)
# Collecting econml==0.15.1
#   Downloading econml-0.15.1-cp39-cp39-win_amd64.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: entrypoints==0.4 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 72)) (0.4)
# Collecting ephem==4.2
#   Downloading ephem-4.2-cp39-cp39-win_amd64.whl (1.4 MB)
#      ---------------------------------------- 1.4/1.4 MB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: erroranalysis==0.5.5 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 74)) (0.5.5)
# Collecting exceptiongroup==1.2.2
#   Downloading exceptiongroup-1.2.2-py3-none-any.whl (16 kB)
# Collecting executing==2.2.0
#   Downloading executing-2.2.0-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: fairlearn==0.7.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 77)) (0.7.0)
# Collecting fire==0.7.0
#   Downloading fire-0.7.0.tar.gz (87 kB)
#      ---------------------------------------- 87.2/87.2 kB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting flask==3.0.3
#   Downloading flask-3.0.3-py3-none-any.whl (101 kB)
#      -------------------------------------- 101.7/101.7 kB 5.7 MB/s eta 0:00:00
# Collecting flask-cors==5.0.1
#   Downloading flask_cors-5.0.1-py3-none-any.whl (11 kB)
# Requirement already satisfied: flatbuffers==25.2.10 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 81)) (25.2.10)
# Collecting fonttools==4.57.0
#   Downloading fonttools-4.57.0-cp39-cp39-win_amd64.whl (2.2 MB)
#      ---------------------------------------- 2.2/2.2 MB 9.3 MB/s eta 0:00:00
# Collecting fsspec==2025.3.2
#   Downloading fsspec-2025.3.2-py3-none-any.whl (194 kB)
#      -------------------------------------- 194.4/194.4 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: fusepy==3.0.1 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 84)) (3.0.1)
# Requirement already satisfied: gensim==4.3.2 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 85)) (4.3.2)
# Requirement already satisfied: gitdb==4.0.12 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 86)) (4.0.12)
# Collecting gitpython==3.1.44
#   Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
#      -------------------------------------- 207.6/207.6 kB 6.2 MB/s eta 0:00:00
# Collecting google-api-core==2.24.2
#   Downloading google_api_core-2.24.2-py3-none-any.whl (160 kB)
#      -------------------------------------- 160.1/160.1 kB 4.8 MB/s eta 0:00:00
# Collecting google-auth==2.38.0
#   Downloading google_auth-2.38.0-py2.py3-none-any.whl (210 kB)
#      -------------------------------------- 210.8/210.8 kB 6.5 MB/s eta 0:00:00
# Collecting googleapis-common-protos==1.70.0
#   Downloading googleapis_common_protos-1.70.0-py3-none-any.whl (294 kB)
#      -------------------------------------- 294.5/294.5 kB 9.2 MB/s eta 0:00:00
# Collecting gunicorn==23.0.0
#   Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
#      ---------------------------------------- 85.0/85.0 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: humanfriendly==10.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 92)) (10.0)
# Collecting idna==3.10
#   Downloading idna-3.10-py3-none-any.whl (70 kB)
#      -------------------------------------- 70.4/70.4 kB 640.4 kB/s eta 0:00:00
# Collecting importlib-metadata==7.2.1
#   Downloading importlib_metadata-7.2.1-py3-none-any.whl (25 kB)
# Requirement already satisfied: importlib-resources==6.4.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 95)) (6.4.0)
# Requirement already satisfied: inference-schema==1.8 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 96)) (1.8)
# Requirement already satisfied: interpret-community==0.31.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 97)) (0.31.0)
# Requirement already satisfied: interpret-core==0.5.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 98)) (0.5.0)
# Requirement already satisfied: ipykernel==6.29.5 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 99)) (6.29.5)
# Collecting ipython==8.18.1
#   Downloading ipython-8.18.1-py3-none-any.whl (808 kB)
#      -------------------------------------- 808.2/808.2 kB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: isodate==0.7.2 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 101)) (0.7.2)
# Requirement already satisfied: itsdangerous==2.2.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 102)) (2.2.0)
# Collecting jedi==0.19.2
#   Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#      ---------------------------------------- 1.6/1.6 MB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: jeepney==0.9.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 104)) (0.9.0)
# Requirement already satisfied: jmespath==0.10.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 105)) (0.10.0)
# Collecting jsonpickle==4.0.5
#   Downloading jsonpickle-4.0.5-py3-none-any.whl (46 kB)
#      ---------------------------------------- 46.4/46.4 kB 2.3 MB/s eta 0:00:00
# Collecting jsonschema==4.23.0
#   Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
#      ---------------------------------------- 88.5/88.5 kB 4.9 MB/s eta 0:00:00
# Collecting jsonschema-specifications==2024.10.1
#   Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Collecting jupyter-client==8.6.3
#   Using cached jupyter_client-8.6.3-py3-none-any.whl (106 kB)
# Collecting jupyter-core==5.7.2
#   Downloading jupyter_core-5.7.2-py3-none-any.whl (28 kB)
# Requirement already satisfied: keras2onnx==1.6.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 111)) (1.6.0)
# Collecting kiwisolver==1.4.7
#   Downloading kiwisolver-1.4.7-cp39-cp39-win_amd64.whl (55 kB)
#      -------------------------------------- 55.8/55.8 kB 970.4 kB/s eta 0:00:00
# Requirement already satisfied: knack==0.12.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 113)) (0.12.0)
# Requirement already satisfied: lightgbm==4.6.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 114)) (4.6.0)
# Requirement already satisfied: locket==1.0.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 115)) (1.0.0)
# Collecting lunarcalendar==0.0.9
#   Downloading LunarCalendar-0.0.9-py2.py3-none-any.whl (18 kB)
# Collecting matplotlib==3.9.4
#   Downloading matplotlib-3.9.4-cp39-cp39-win_amd64.whl (7.8 MB)
#      ---------------------------------------- 7.8/7.8 MB 11.1 MB/s eta 0:00:00
# Collecting matplotlib-inline==0.1.7
#   Downloading matplotlib_inline-0.1.7-py3-none-any.whl (9.9 kB)
# Requirement already satisfied: ml-wrappers==0.5.6 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 119)) (0.5.6)
# Collecting mlflow-skinny==2.15.1
#   Downloading mlflow_skinny-2.15.1-py3-none-any.whl (5.5 MB)
#      ---------------------------------------- 5.5/5.5 MB 8.8 MB/s eta 0:00:00
# Collecting mltable==1.6.1
#   Downloading mltable-1.6.1-py3-none-any.whl (189 kB)
#      -------------------------------------- 189.4/189.4 kB 5.8 MB/s eta 0:00:00
# Collecting msal==1.32.0
#   Downloading msal-1.32.0-py3-none-any.whl (114 kB)
#      -------------------------------------- 114.7/114.7 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: msal-extensions==1.3.1 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 123)) (1.3.1)
# Collecting msgpack==1.1.0
#   Downloading msgpack-1.1.0-cp39-cp39-win_amd64.whl (74 kB)
#      ---------------------------------------- 74.8/74.8 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: msrest==0.7.1 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 125)) (0.7.1)
# Requirement already satisfied: msrestazure==0.6.4.post1 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 126)) (0.6.4.post1)
# Requirement already satisfied: ndg-httpsclient==0.5.1 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 127)) (0.5.1)
# Collecting nest-asyncio==1.6.0
#   Downloading nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Requirement already satisfied: networkx==2.5 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 129)) (2.5)
# Collecting numba==0.56.4
#   Downloading numba-0.56.4-cp39-cp39-win_amd64.whl (2.5 MB)
#      ---------------------------------------- 2.5/2.5 MB 9.2 MB/s eta 0:00:00
# Collecting oauthlib==3.2.2
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Collecting onnx==1.17.0
#   Using cached onnx-1.17.0-cp39-cp39-win_amd64.whl (14.5 MB)
# Requirement already satisfied: onnxconverter-common==1.13.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 133)) (1.13.0)
# Requirement already satisfied: onnxmltools==1.12.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 134)) (1.12.0)
# Collecting onnxruntime==1.17.3
#   Using cached onnxruntime-1.17.3-cp39-cp39-win_amd64.whl (5.6 MB)
# Collecting opencensus==0.11.4
#   Downloading opencensus-0.11.4-py2.py3-none-any.whl (128 kB)
#      -------------------------------------- 128.2/128.2 kB 7.4 MB/s eta 0:00:00
# Collecting opencensus-context==0.1.3
#   Downloading opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Collecting opencensus-ext-azure==1.1.14
#   Downloading opencensus_ext_azure-1.1.14-py2.py3-none-any.whl (43 kB)
#      ---------------------------------------- 43.4/43.4 kB 2.2 MB/s eta 0:00:00
# Collecting opentelemetry-api==1.32.0
#   Downloading opentelemetry_api-1.32.0-py3-none-any.whl (65 kB)
#      ---------------------------------------- 65.3/65.3 kB ? eta 0:00:00
# Collecting opentelemetry-sdk==1.32.0
#   Downloading opentelemetry_sdk-1.32.0-py3-none-any.whl (118 kB)
#      -------------------------------------- 119.0/119.0 kB 7.2 MB/s eta 0:00:00
# Collecting opentelemetry-semantic-conventions==0.53b0
#   Downloading opentelemetry_semantic_conventions-0.53b0-py3-none-any.whl (188 kB)
#      -------------------------------------- 188.4/188.4 kB 5.6 MB/s eta 0:00:00
# Collecting packaging==24.2
#   Using cached packaging-24.2-py3-none-any.whl (65 kB)
# Collecting paramiko==3.5.1
#   Using cached paramiko-3.5.1-py3-none-any.whl (227 kB)
# Collecting parso==0.8.4
#   Downloading parso-0.8.4-py2.py3-none-any.whl (103 kB)
#      -------------------------------------- 103.7/103.7 kB 3.0 MB/s eta 0:00:00
# Collecting partd==1.4.2
#   Downloading partd-1.4.2-py3-none-any.whl (18 kB)
# Collecting pathspec==0.12.1
#   Using cached pathspec-0.12.1-py3-none-any.whl (31 kB)
# Collecting patsy==1.0.1
#   Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
#      -------------------------------------- 232.9/232.9 kB 7.2 MB/s eta 0:00:00
# Collecting pexpect==4.9.0
#   Downloading pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
#      ---------------------------------------- 63.8/63.8 kB 3.3 MB/s eta 0:00:00
# Collecting pillow==11.2.1
#   Downloading pillow-11.2.1-cp39-cp39-win_amd64.whl (2.7 MB)
#      ---------------------------------------- 2.7/2.7 MB 10.7 MB/s eta 0:00:00
# Collecting pkginfo==1.12.1.2
#   Using cached pkginfo-1.12.1.2-py3-none-any.whl (32 kB)
# Collecting platformdirs==4.3.7
#   Downloading platformdirs-4.3.7-py3-none-any.whl (18 kB)
# Requirement already satisfied: pmdarima==1.8.5 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 152)) (1.8.5)
# Collecting prompt-toolkit==3.0.50
#   Downloading prompt_toolkit-3.0.50-py3-none-any.whl (387 kB)
#      -------------------------------------- 387.8/387.8 kB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: property-cached==1.6.4 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 154)) (1.6.4)
# Collecting prophet==1.1.4
#   Downloading prophet-1.1.4-py3-none-win_amd64.whl (12.9 MB)
#      ---------------------------------------- 12.9/12.9 MB 7.1 MB/s eta 0:00:00
# Collecting proto-plus==1.26.1
#   Downloading proto_plus-1.26.1-py3-none-any.whl (50 kB)
#      ---------------------------------------- 50.2/50.2 kB 2.7 MB/s eta 0:00:00
# Collecting protobuf==5.29.4
#   Downloading protobuf-5.29.4-cp39-cp39-win_amd64.whl (434 kB)
#      -------------------------------------- 434.6/434.6 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: ptyprocess==0.7.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 158)) (0.7.0)
# Collecting pure-eval==0.2.3
#   Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Collecting pyarrow==14.0.2
#   Using cached pyarrow-14.0.2-cp39-cp39-win_amd64.whl (24.6 MB)
# Collecting pyasn1==0.6.1
#   Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
#      ---------------------------------------- 83.1/83.1 kB 4.9 MB/s eta 0:00:00
# Collecting pyasn1-modules==0.4.2
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
#      ------------------------------------- 181.3/181.3 kB 10.7 MB/s eta 0:00:00
# Collecting pycparser==2.22
#   Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Collecting pydantic==2.9.2
#   Downloading pydantic-2.9.2-py3-none-any.whl (434 kB)
#      -------------------------------------- 434.9/434.9 kB 6.8 MB/s eta 0:00:00
# Collecting pydantic-core==2.23.4
#   Downloading pydantic_core-2.23.4-cp39-none-win_amd64.whl (1.9 MB)
#      ---------------------------------------- 1.9/1.9 MB 10.2 MB/s eta 0:00:00
# Collecting pydantic-settings==2.8.1
#   Downloading pydantic_settings-2.8.1-py3-none-any.whl (30 kB)
# Collecting pygments==2.19.1
#   Downloading pygments-2.19.1-py3-none-any.whl (1.2 MB)
#      ---------------------------------------- 1.2/1.2 MB 2.8 MB/s eta 0:00:00
# Collecting pyjwt==2.10.1
#   Using cached PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Collecting pymeeus==0.5.12
#   Downloading PyMeeus-0.5.12.tar.gz (5.8 MB)
#      ---------------------------------------- 5.8/5.8 MB 9.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pynacl==1.5.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 170)) (1.5.0)
# Collecting pyopenssl==25.0.0
#   Downloading pyOpenSSL-25.0.0-py3-none-any.whl (56 kB)
#      ---------------------------------------- 56.5/56.5 kB ? eta 0:00:00
# Collecting pyparsing==3.2.3
#   Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
#      -------------------------------------- 111.1/111.1 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: pysocks==1.7.1 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 173)) (1.7.1)
# Collecting python-dateutil==2.9.0.post0
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#      -------------------------------------- 229.9/229.9 kB 4.8 MB/s eta 0:00:00
# Collecting python-dotenv==1.1.0
#   Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Collecting pytz==2024.2
#   Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
#      -------------------------------------- 508.0/508.0 kB 6.4 MB/s eta 0:00:00
# Collecting pyzmq==26.4.0
#   Downloading pyzmq-26.4.0-cp39-cp39-win_amd64.whl (644 kB)
#      -------------------------------------- 644.3/644.3 kB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: raiutils==0.4.2 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 178)) (0.4.2)
# Collecting referencing==0.36.2
#   Downloading referencing-0.36.2-py3-none-any.whl (26 kB)
# Collecting requests==2.32.3
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ---------------------------------------- 64.9/64.9 kB ? eta 0:00:00
# Requirement already satisfied: requests-oauthlib==2.0.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 181)) (2.0.0)
# Requirement already satisfied: responsibleai==0.36.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 182)) (0.36.0)
# Collecting rpds-py==0.24.0
#   Downloading rpds_py-0.24.0-cp39-cp39-win_amd64.whl (234 kB)
#      -------------------------------------- 234.9/234.9 kB 7.0 MB/s eta 0:00:00
# Collecting rsa==4.9
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: s3transfer==0.5.2 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 185)) (0.5.2)
# Collecting scipy==1.10.1
#   Downloading scipy-1.10.1-cp39-cp39-win_amd64.whl (42.5 MB)
#      ---------------------------------------- 42.5/42.5 MB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: secretstorage==3.3.3 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 187)) (3.3.3)
# Requirement already satisfied: semver==2.13.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 188)) (2.13.0)
# Collecting six==1.17.0
#   Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: skl2onnx==1.15.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 190)) (1.15.0)
# Requirement already satisfied: sklearn-pandas==1.7.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 191)) (1.7.0)
# Requirement already satisfied: slicer==0.0.7 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 192)) (0.0.7)
# Requirement already satisfied: smart-open==6.4.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 193)) (6.4.0)
# Requirement already satisfied: smmap==5.0.2 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 194)) (5.0.2)
# Requirement already satisfied: sortedcontainers==2.4.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 195)) (2.4.0)
# Requirement already satisfied: sparse==0.15.5 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 196)) (0.15.5)
# Requirement already satisfied: sqlparse==0.5.3 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 197)) (0.5.3)
# Collecting stack-data==0.6.3
#   Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Collecting stanio==0.5.1
#   Downloading stanio-0.5.1-py3-none-any.whl (8.1 kB)
# Collecting statsmodels==0.13.5
#   Downloading statsmodels-0.13.5-cp39-cp39-win_amd64.whl (9.2 MB)
#      ---------------------------------------- 9.2/9.2 MB 7.8 MB/s eta 0:00:00
# Collecting tabulate==0.9.0
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting tblib==3.1.0
#   Downloading tblib-3.1.0-py3-none-any.whl (12 kB)
# Collecting termcolor==3.0.1
#   Downloading termcolor-3.0.1-py3-none-any.whl (7.2 kB)
# Requirement already satisfied: threadpoolctl==3.6.0 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 204)) (3.6.0)
# Collecting toolz==1.0.0
#   Downloading toolz-1.0.0-py3-none-any.whl (56 kB)
#      ---------------------------------------- 56.4/56.4 kB 2.9 MB/s eta 0:00:00
# Collecting tornado==6.4.2
#   Downloading tornado-6.4.2-cp38-abi3-win_amd64.whl (438 kB)
#      -------------------------------------- 438.9/438.9 kB 5.5 MB/s eta 0:00:00
# Collecting tqdm==4.67.1
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#      -------------------------------------- 78.5/78.5 kB 484.4 kB/s eta 0:00:00
# Requirement already satisfied: traitlets==5.14.3 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 208)) (5.14.3)
# Requirement already satisfied: urllib3==1.26.20 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 209)) (1.26.20)
# Collecting wcwidth==0.2.13
#   Downloading wcwidth-0.2.13-py2.py3-none-any.whl (34 kB)
# Requirement already satisfied: werkzeug==3.1.3 in c:\users\jnare\anaconda3\lib\site-packages (from -r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 211)) (3.1.3)
# Collecting wrapt==1.16.0
#   Downloading wrapt-1.16.0-cp39-cp39-win_amd64.whl (37 kB)
# Collecting xgboost==1.5.2
#   Downloading xgboost-1.5.2-py3-none-win_amd64.whl (106.6 MB)
#      -------------------------------------- 106.6/106.6 MB 1.4 MB/s eta 0:00:00
# Collecting zict==3.0.0
#   Downloading zict-3.0.0-py2.py3-none-any.whl (43 kB)
#      ---------------------------------------- 43.3/43.3 kB ? eta 0:00:00
# Collecting zipp==3.21.0
#   Downloading zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: pandas>=1.0 in c:\users\jnare\anaconda3\lib\site-packages (from arch==5.6.0->-r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 4)) (1.5.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\jnare\anaconda3\lib\site-packages (from arch==5.6.0->-r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 4)) (1.21.6)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\jnare\anaconda3\lib\site-packages (from azure-core==1.33.0->-r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 9)) (4.14.1)
# Requirement already satisfied: psutil<5.9.4,>=5.2.2 in c:\users\jnare\anaconda3\lib\site-packages (from azureml-automl-runtime==1.60.0->-r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 22)) (5.9.0)
# Requirement already satisfied: scikit-learn~=1.5.1 in c:\users\jnare\anaconda3\lib\site-packages (from azureml-automl-runtime==1.60.0->-r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 22)) (1.5.1)
# Requirement already satisfied: joblib==1.2.0 in c:\users\jnare\anaconda3\lib\site-packages (from azureml-automl-runtime==1.60.0->-r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 22)) (1.2.0)
# Requirement already satisfied: botocore<=1.23.19 in c:\users\jnare\anaconda3\lib\site-packages (from azureml-automl-runtime==1.60.0->-r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 22)) (1.23.19)
# Requirement already satisfied: boto3<=1.20.19 in c:\users\jnare\anaconda3\lib\site-packages (from azureml-automl-runtime==1.60.0->-r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 22)) (1.20.19)
# Requirement already satisfied: requests[socks]<3.0.0,>=2.19.1 in c:\users\jnare\anaconda3\lib\site-packages (from azureml-core==1.60.0->-r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 23)) (2.28.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.1.0 in c:\users\jnare\anaconda3\lib\site-packages (from azureml-dataprep==5.1.6->-r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 24)) (6.0)
# Requirement already satisfied: cloudpickle<3.0.0,>=1.1.0 in c:\users\jnare\anaconda3\lib\site-packages (from azureml-dataprep==5.1.6->-r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 24)) (2.0.0)
# Requirement already satisfied: waitress>=3.0.1 in c:\users\jnare\anaconda3\lib\site-packages (from azureml-inference-server-http==1.4.0->-r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 29)) (3.0.2)
# Requirement already satisfied: dask[complete]<=2023.2.0 in c:\users\jnare\anaconda3\lib\site-packages (from azureml-train-automl-runtime==1.60.0->-r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 37)) (2022.7.0)
# Requirement already satisfied: jinja2<4 in c:\users\jnare\anaconda3\lib\site-packages (from azureml-train-automl-runtime==1.60.0->-r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 37)) (3.1.6)
# Collecting numpy>=1.17
#   Using cached numpy-1.23.5-cp39-cp39-win_amd64.whl (14.7 MB)
# Requirement already satisfied: click>=7.0 in c:\users\jnare\anaconda3\lib\site-packages (from dask==2023.2.0->-r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 59)) (8.1.8)
# Requirement already satisfied: pywin32>=304 in c:\users\jnare\anaconda3\lib\site-packages (from docker==7.1.0->-r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 69)) (311)
# Collecting shap<0.44.0,>=0.38.1
#   Downloading shap-0.43.0-cp39-cp39-win_amd64.whl (447 kB)
#      ------------------------------------- 447.3/447.3 kB 13.7 MB/s eta 0:00:00
# Requirement already satisfied: pyreadline3 in c:\users\jnare\anaconda3\lib\site-packages (from humanfriendly==10.0->-r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 92)) (3.5.4)
# Requirement already satisfied: colorama in c:\users\jnare\anaconda3\lib\site-packages (from ipython==8.18.1->-r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 100)) (0.4.5)
# Requirement already satisfied: PyJWT[crypto]<3,>=1.0.0 in c:\users\jnare\anaconda3\lib\site-packages (from msal==1.32.0->-r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 122)) (2.4.0)
# Collecting llvmlite<0.40,>=0.39.0dev0
#   Downloading llvmlite-0.39.1-cp39-cp39-win_amd64.whl (23.2 MB)
#      ---------------------------------------- 23.2/23.2 MB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in c:\users\jnare\anaconda3\lib\site-packages (from numba==0.56.4->-r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 130)) (63.4.1)
# Requirement already satisfied: sympy in c:\users\jnare\anaconda3\lib\site-packages (from onnxruntime==1.17.3->-r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 135)) (1.10.1)
# Collecting holidays>=0.25
#   Downloading holidays-0.79-py3-none-any.whl (1.2 MB)
#      ---------------------------------------- 1.2/1.2 MB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\jnare\anaconda3\lib\site-packages (from werkzeug==3.1.3->-r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 211)) (3.0.2)
# Collecting requests[socks]<3.0.0,>=2.19.1
#   Downloading requests-2.32.5-py3-none-any.whl (64 kB)
#      ---------------------------------------- 64.7/64.7 kB ? eta 0:00:00
#   Downloading requests-2.32.4-py3-none-any.whl (64 kB)
#      ---------------------------------------- 64.8/64.8 kB ? eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in c:\users\jnare\anaconda3\lib\site-packages (from sympy->onnxruntime==1.17.3->-r C:\Users\jnare\OneDrive\Documents\sowmya\github_projects\local_model\best\mlflow-model\requirements.txt (line 135)) (1.2.1)
# Building wheels for collected packages: fire, pymeeus
#   Building wheel for fire (setup.py): started
#   Building wheel for fire (setup.py): finished with status 'done'
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114247 sha256=5ed4179dd161e9a2a33641fb106c9618f71da55811fddfba37bcf3674868ae76
#   Stored in directory: c:\users\jnare\appdata\local\pip\cache\wheels\3b\ee\ac\319a7b7f331f61050d0d54425079b2a883b445be3c7284a4eb
#   Building wheel for pymeeus (setup.py): started
#   Building wheel for pymeeus (setup.py): finished with status 'done'
#   Created wheel for pymeeus: filename=PyMeeus-0.5.12-py3-none-any.whl size=732001 sha256=2c3924f3f8215808a3ce62f96dd1a185a7edd7a556b9c7654e1bebe5630e9953
#   Stored in directory: c:\users\jnare\appdata\local\pip\cache\wheels\04\1f\e5\8dd0c661cd8d252817655dc14a84f7ae045d6616594145aa81
# Successfully built fire pymeeus
# Installing collected packages: wcwidth, pytz, pymeeus, pure-eval, opencensus-context, ephem, zipp, zict, wrapt, tqdm, tornado, toolz, termcolor, tblib, tabulate, six, rpds-py, pyzmq, python-dotenv, pyparsing, pyjwt, pygments, pydantic-core, pycparser, pyasn1, protobuf, prompt-toolkit, platformdirs, pkginfo, pillow, pexpect, pathspec, parso, packaging, oauthlib, numpy, nest-asyncio, msgpack, matplotlib-inline, llvmlite, kiwisolver, jsonpickle, idna, fsspec, fonttools, executing, exceptiongroup, dill, decorator, debugpy, cython, cycler, convertdate, comm, charset-normalizer, certifi, bcrypt, attrs, asttokens, stanio, stack-data, scipy, rsa, requests, referencing, python-dateutil, pydantic, pyasn1-modules, pyarrow, proto-plus, patsy, partd, onnx, numba, jupyter-core, jedi, importlib-metadata, gunicorn, googleapis-common-protos, gitpython, fire, contourpy, cffi, xgboost, pydantic-settings, opentelemetry-api, onnxruntime, matplotlib, lunarcalendar, jupyter-client, jsonschema-specifications, ipython, holidays, google-auth, flask, dask, cryptography, azure-core, statsmodels, shap, pyopenssl, paramiko, opentelemetry-semantic-conventions, jsonschema, google-api-core, flask-cors, distributed, databricks-sdk, cmdstanpy, azure-storage-queue, azure-storage-blob, azure-mgmt-core, prophet, opentelemetry-sdk, opencensus, msal, econml, azure-mgmt-storage, azure-mgmt-resource, azure-mgmt-network, azure-mgmt-keyvault, azure-mgmt-containerregistry, mlflow-skinny, azureml-core, azure-identity, opencensus-ext-azure, azureml-pipeline-core, azureml-mlflow, azureml-inference-server-http, mltable
#   Attempting uninstall: wcwidth
#     Found existing installation: wcwidth 0.2.5
#     Uninstalling wcwidth-0.2.5:
#       Successfully uninstalled wcwidth-0.2.5
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2022.1
#     Uninstalling pytz-2022.1:
#       Successfully uninstalled pytz-2022.1
#   Attempting uninstall: zipp
#     Found existing installation: zipp 3.8.0
#     Uninstalling zipp-3.8.0:
#       Successfully uninstalled zipp-3.8.0
#   Attempting uninstall: zict
#     Found existing installation: zict 2.1.0
#     Uninstalling zict-2.1.0:
#       Successfully uninstalled zict-2.1.0
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.14.1
#     Uninstalling wrapt-1.14.1:
#       Successfully uninstalled wrapt-1.14.1
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.1
#     Uninstalling tqdm-4.64.1:
#       Successfully uninstalled tqdm-4.64.1
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.1
#     Uninstalling tornado-6.1:
#       Successfully uninstalled tornado-6.1
#   Attempting uninstall: toolz
#     Found existing installation: toolz 0.11.2
#     Uninstalling toolz-0.11.2:
#       Successfully uninstalled toolz-0.11.2
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 3.1.0
#     Uninstalling termcolor-3.1.0:
#       Successfully uninstalled termcolor-3.1.0
#   Attempting uninstall: tblib
#     Found existing installation: tblib 1.7.0
#     Uninstalling tblib-1.7.0:
#       Successfully uninstalled tblib-1.7.0
#   Attempting uninstall: tabulate
#     Found existing installation: tabulate 0.8.10
#     Uninstalling tabulate-0.8.10:
#       Successfully uninstalled tabulate-0.8.10
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 27.0.1
#     Uninstalling pyzmq-27.0.1:
#       Successfully uninstalled pyzmq-27.0.1
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\jnare\\anaconda3\\Lib\\site-packages\\~mq\\backend\\cython\\_zmq.cp39-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
import mlflow
import pandas as pd

# Load MLflow model
model = mlflow.pyfunc.load_model("./local_model/best/mlflow-model")

# Example: use a row from your engineered walmart.csv
sample = pd.read_csv("./walmart_data/walmart.csv").head(10).drop(columns=["weekly_sales"])
# Cast columns to match MLTable schema
sample ['store'] = sample ['store'].astype(str)      # AutoML expects string
sample ['dept'] = sample ['dept'].astype(int)        # AutoML expects long (int64)
sample['isholiday'] = sample['isholiday'].astype(bool)

# Dates already handled as datetime
sample['date'] = pd.to_datetime(sample['date'], errors='coerce')

# Save clean dataset
sample.to_csv("walmart.csv", index=False)

# Predict
prediction = model.predict(sample)
print("Predicted Weekly Sales:", prediction)
# Out:
# 2025/08/22 23:38:59 WARNING mlflow.utils.requirements_utils: Encountered an unexpected error (AttributeError("module 'opencensus' has no attribute '__version__'")) while detecting model dependency mismatches. Set logging level to DEBUG to see the full traceback.
# Predicted Weekly Sales: [24294.40945699 40575.95483054 37210.49598947 27877.87220515
#  27499.04705998 26364.52126504 25515.23061713 28077.24454628
#  55138.10967538 36689.71842458]
